# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn import preprocessing
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score,roc_curve,classification_report,roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.model_selection import RandomizedSearchCV

from time import time
from joblib import dump
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from scikeras.wrappers import KerasRegressor 
from sklearn.model_selection import GridSearchCV


from sklearn.dummy import DummyRegressor

from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor
from catboost import CatBoostRegressor

from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from xgboost import XGBRegressor

from sklearn.svm import SVR
from sklearn.svm import LinearSVR

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize

#from skopt import BayesSearchCV
#from skopt.space import Real, Categorical, Integer

# %%
df=pd.read_csv('ml_dataset_angles.csv')
df_rounded=df

# %%
x=df_rounded[['Speed (mm/s)','Flowrate (Hz)','deposition_ratio']]
y=df_rounded['Angle_dev (deg)']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, 
                                                    random_state=42)

print(X_train.shape)
print(X_test.shape)
# Out:
# (324, 3)
# (81, 3)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
X_train = normalize(X_train)
X_val = normalize(X_val)
X_test = normalize(X_test)

# %%
def instantiate_model(model_name):
    model = model_name()
    return model

def fit_model(model, X_train, y_train):
    ti = time()
    model = instantiate_model(model)
    model.fit(X_train, y_train)
    fit_time = time() - ti
    return model, fit_time

def evaluate_model(model, X, y_act):
    y_pred = model.predict(X)
    r2 = r2_score(y_act, y_pred)
    mae = mean_absolute_error(y_act, y_pred)
    rmse_val = mean_squared_error(y_act, y_pred, squared=False)
    return r2, mae, rmse_val

def fit_evaluate_model(model, model_name, X_train, y_train, X_val, y_act_val):
    model, fit_time = fit_model(model, X_train, y_train)
    r2_train, mae_train, rmse_train = evaluate_model(model, X_train, y_train)
    r2_val, mae_val, rmse_val = evaluate_model(model, X_val, y_act_val)
    result_dict = {
        'model_name': model_name,
        'model_name_pretty': type(model).__name__,
        'model_params': model.get_params(),
        'fit_time': fit_time,
        'r2_train': r2_train,
        'mae_train': mae_train,
        'rmse_train': rmse_train,
        'r2_val': r2_val,
        'mae_val': mae_val,
        'rmse_val': rmse_val}
    return model, result_dict

def append_result_df(df, result_dict):
    df_result_appended = df.append(result_dict, ignore_index=True)
    return df_result_appended

def append_model_dict(dic, model_name, model):
    dic[model_name] = model
    return dic

# %%
df_classics = pd.DataFrame(columns=['model_name',
                                    'model_name_pretty',
                                    'model_params',
                                    'fit_time',
                                    'r2_train',
                                    'mae_train',
                                    'rmse_train',
                                    'r2_val',
                                    'mae_val',
                                    'rmse_val'])
df_classics
# Out:
# Empty DataFrame
# Columns: [model_name, model_name_pretty, model_params, fit_time, r2_train, mae_train, rmse_train, r2_val, mae_val, rmse_val]
# Index: []

# %%
# Build a dictionary of model names
from collections import OrderedDict
classic_model_names = OrderedDict({
    'dumr': DummyRegressor,
    'rr': Ridge,
    'abr': AdaBoostRegressor,
    'gbr': GradientBoostingRegressor,
    'rfr': RandomForestRegressor,
    'etr': ExtraTreesRegressor,
    'DT': DecisionTreeRegressor,
    'KNR': KNeighborsRegressor,
    'svr': SVR,
    'lsvr': LinearSVR,
    'CBR': CatBoostRegressor,
    'LR': LinearRegression,
    'XGB': XGBRegressor
})

# %%
# Instantiate a dictionary to store the model objects
classic_models = OrderedDict()

# Keep track of elapsed time
ti = time()

# Loop through each model type, fit and predict, and evaluate and store results
for model_name, model in classic_model_names.items():
    print(f'Now fitting and evaluating model {model_name}: {model.__name__}')
    model, result_dict = fit_evaluate_model(model, model_name, X_train, y_train, X_val, y_val)
    df_classics = pd.concat([df_classics, pd.DataFrame([result_dict])], ignore_index=True)
    classic_models = append_model_dict(classic_models, model_name, model)

dt = time() - ti
print(f'Finished fitting {len(classic_models)} models, total time: {dt:0.2f} s')
# Out:
# Now fitting and evaluating model dumr: DummyRegressor
# Now fitting and evaluating model rr: Ridge
# Now fitting and evaluating model abr: AdaBoostRegressor
# Now fitting and evaluating model gbr: GradientBoostingRegressor
# C:\Users\Ahmad\AppData\Local\Temp\ipykernel_20392\3087810594.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_classics = pd.concat([df_classics, pd.DataFrame([result_dict])], ignore_index=True)
# Now fitting and evaluating model rfr: RandomForestRegressor
# Now fitting and evaluating model etr: ExtraTreesRegressor
# Now fitting and evaluating model DT: DecisionTreeRegressor
# Now fitting and evaluating model KNR: KNeighborsRegressor
# Now fitting and evaluating model svr: SVR
# Now fitting and evaluating model lsvr: LinearSVR
# Now fitting and evaluating model CBR: CatBoostRegressor
# Learning rate set to 0.033388
# 0:	learn: 6.3081627	total: 132ms	remaining: 2m 11s
# 1:	learn: 6.2333724	total: 135ms	remaining: 1m 7s
# 2:	learn: 6.1783514	total: 139ms	remaining: 46.3s
# 3:	learn: 6.1250191	total: 143ms	remaining: 35.6s
# 4:	learn: 6.0599116	total: 146ms	remaining: 29.1s
# 5:	learn: 6.0091389	total: 150ms	remaining: 24.8s
# 6:	learn: 5.9568547	total: 154ms	remaining: 21.8s
# 7:	learn: 5.9145909	total: 157ms	remaining: 19.5s
# 8:	learn: 5.8585111	total: 161ms	remaining: 17.7s
# 9:	learn: 5.8208276	total: 165ms	remaining: 16.4s
# 10:	learn: 5.7850210	total: 170ms	remaining: 15.3s
# 11:	learn: 5.7333721	total: 176ms	remaining: 14.5s
# 12:	learn: 5.7003623	total: 180ms	remaining: 13.7s
# 13:	learn: 5.6573233	total: 184ms	remaining: 12.9s
# 14:	learn: 5.6247447	total: 188ms	remaining: 12.4s
# 15:	learn: 5.5825845	total: 193ms	remaining: 11.9s
# 16:	learn: 5.5485926	total: 197ms	remaining: 11.4s
# 17:	learn: 5.5204857	total: 201ms	remaining: 10.9s
# 18:	learn: 5.4856147	total: 204ms	remaining: 10.5s
# 19:	learn: 5.4545185	total: 208ms	remaining: 10.2s
# 20:	learn: 5.4308322	total: 212ms	remaining: 9.87s
# 21:	learn: 5.4033632	total: 216ms	remaining: 9.59s
# 22:	learn: 5.3706015	total: 219ms	remaining: 9.32s
# 23:	learn: 5.3437413	total: 222ms	remaining: 9.05s
# 354:	learn: 3.2838000	total: 1.09s	remaining: 1.99s
# 355:	learn: 3.2828250	total: 1.1s	remaining: 1.99s
# 356:	learn: 3.2804259	total: 1.1s	remaining: 1.98s
# 357:	learn: 3.2794711	total: 1.1s	remaining: 1.98s
# 358:	learn: 3.2785333	total: 1.1s	remaining: 1.97s
# 359:	learn: 3.2776206	total: 1.1s	remaining: 1.97s
# 360:	learn: 3.2759392	total: 1.11s	remaining: 1.96s
# 361:	learn: 3.2720762	total: 1.11s	remaining: 1.95s
# 362:	learn: 3.2711740	total: 1.11s	remaining: 1.95s
# 363:	learn: 3.2672337	total: 1.11s	remaining: 1.94s
# 364:	learn: 3.2625952	total: 1.11s	remaining: 1.94s
# 365:	learn: 3.2592919	total: 1.11s	remaining: 1.93s
# 366:	learn: 3.2572252	total: 1.11s	remaining: 1.92s
# 367:	learn: 3.2533978	total: 1.12s	remaining: 1.92s
# 368:	learn: 3.2525177	total: 1.12s	remaining: 1.91s
# 369:	learn: 3.2509110	total: 1.12s	remaining: 1.91s
# 370:	learn: 3.2464438	total: 1.12s	remaining: 1.9s
# 371:	learn: 3.2448932	total: 1.12s	remaining: 1.9s
# 372:	learn: 3.2405402	total: 1.12s	remaining: 1.89s
# 373:	learn: 3.2396710	total: 1.13s	remaining: 1.89s
# 374:	learn: 3.2356185	total: 1.13s	remaining: 1.88s
# 375:	learn: 3.2319930	total: 1.13s	remaining: 1.87s
# 376:	learn: 3.2304951	total: 1.13s	remaining: 1.87s
# 377:	learn: 3.2264949	total: 1.13s	remaining: 1.86s
# 378:	learn: 3.2223037	total: 1.13s	remaining: 1.86s
# 379:	learn: 3.2202528	total: 1.13s	remaining: 1.85s
# 380:	learn: 3.2194085	total: 1.14s	remaining: 1.84s
# 381:	learn: 3.2185793	total: 1.14s	remaining: 1.84s
# 382:	learn: 3.2165611	total: 1.14s	remaining: 1.83s
# 383:	learn: 3.2126767	total: 1.14s	remaining: 1.83s
# 384:	learn: 3.2106893	total: 1.14s	remaining: 1.82s
# 385:	learn: 3.2098773	total: 1.14s	remaining: 1.82s
# 386:	learn: 3.2090798	total: 1.15s	remaining: 1.81s
# 387:	learn: 3.2052901	total: 1.15s	remaining: 1.81s
# 388:	learn: 3.2033320	total: 1.15s	remaining: 1.8s
# 389:	learn: 3.2025514	total: 1.15s	remaining: 1.8s
# 390:	learn: 3.2010974	total: 1.15s	remaining: 1.79s
# 391:	learn: 3.2003300	total: 1.15s	remaining: 1.79s
# 392:	learn: 3.1966316	total: 1.16s	remaining: 1.78s
# 393:	learn: 3.1947021	total: 1.16s	remaining: 1.78s
# 394:	learn: 3.1875393	total: 1.16s	remaining: 1.78s
# 395:	learn: 3.1840188	total: 1.16s	remaining: 1.77s
# 396:	learn: 3.1826100	total: 1.16s	remaining: 1.77s
# 397:	learn: 3.1791313	total: 1.17s	remaining: 1.76s
# 398:	learn: 3.1770630	total: 1.17s	remaining: 1.76s
# 399:	learn: 3.1763196	total: 1.17s	remaining: 1.75s
# 491:	learn: 2.9718758	total: 1.39s	remaining: 1.44s
# 492:	learn: 2.9702695	total: 1.39s	remaining: 1.43s
# 493:	learn: 2.9697244	total: 1.39s	remaining: 1.43s
# 494:	learn: 2.9690894	total: 1.4s	remaining: 1.42s
# 495:	learn: 2.9673584	total: 1.4s	remaining: 1.42s
# 496:	learn: 2.9639919	total: 1.4s	remaining: 1.42s
# 497:	learn: 2.9624090	total: 1.4s	remaining: 1.41s
# 498:	learn: 2.9607379	total: 1.4s	remaining: 1.41s
# 499:	learn: 2.9590841	total: 1.41s	remaining: 1.41s
# 500:	learn: 2.9585474	total: 1.41s	remaining: 1.4s
# 501:	learn: 2.9571188	total: 1.41s	remaining: 1.4s
# 502:	learn: 2.9555591	total: 1.41s	remaining: 1.4s
# 503:	learn: 2.9541578	total: 1.41s	remaining: 1.39s
# 504:	learn: 2.9536294	total: 1.42s	remaining: 1.39s
# 505:	learn: 2.9520943	total: 1.42s	remaining: 1.38s
# 506:	learn: 2.9515766	total: 1.42s	remaining: 1.38s
# 507:	learn: 2.9484018	total: 1.42s	remaining: 1.38s
# 508:	learn: 2.9470504	total: 1.42s	remaining: 1.37s
# 509:	learn: 2.9454665	total: 1.43s	remaining: 1.37s
# 510:	learn: 2.9439336	total: 1.43s	remaining: 1.37s
# 511:	learn: 2.9424196	total: 1.43s	remaining: 1.36s
# 512:	learn: 2.9419121	total: 1.44s	remaining: 1.36s
# 513:	learn: 2.9414081	total: 1.44s	remaining: 1.36s
# 514:	learn: 2.9399181	total: 1.44s	remaining: 1.36s
# 515:	learn: 2.9394266	total: 1.44s	remaining: 1.35s
# 516:	learn: 2.9389459	total: 1.45s	remaining: 1.35s
# 517:	learn: 2.9374368	total: 1.45s	remaining: 1.35s
# 518:	learn: 2.9351815	total: 1.45s	remaining: 1.34s
# 519:	learn: 2.9337359	total: 1.45s	remaining: 1.34s
# 520:	learn: 2.9323141	total: 1.46s	remaining: 1.34s
# 521:	learn: 2.9318404	total: 1.46s	remaining: 1.33s
# 522:	learn: 2.9297503	total: 1.46s	remaining: 1.33s
# 523:	learn: 2.9292829	total: 1.46s	remaining: 1.33s
# 524:	learn: 2.9288216	total: 1.47s	remaining: 1.32s
# 525:	learn: 2.9283721	total: 1.47s	remaining: 1.32s
# 526:	learn: 2.9270869	total: 1.47s	remaining: 1.32s
# 527:	learn: 2.9266431	total: 1.47s	remaining: 1.31s
# 528:	learn: 2.9262043	total: 1.47s	remaining: 1.31s
# 529:	learn: 2.9257756	total: 1.48s	remaining: 1.31s
# 530:	learn: 2.9252334	total: 1.48s	remaining: 1.31s
# 531:	learn: 2.9248120	total: 1.48s	remaining: 1.3s
# 532:	learn: 2.9227666	total: 1.49s	remaining: 1.3s
# 533:	learn: 2.9223490	total: 1.49s	remaining: 1.3s
# 534:	learn: 2.9219389	total: 1.49s	remaining: 1.3s
# 535:	learn: 2.9201578	total: 1.5s	remaining: 1.29s
# 536:	learn: 2.9197565	total: 1.5s	remaining: 1.29s
# 537:	learn: 2.9193622	total: 1.5s	remaining: 1.29s
# 538:	learn: 2.9180285	total: 1.5s	remaining: 1.28s
# 539:	learn: 2.9176377	total: 1.51s	remaining: 1.28s
# 540:	learn: 2.9172537	total: 1.51s	remaining: 1.28s
# 541:	learn: 2.9162330	total: 1.51s	remaining: 1.28s
# 542:	learn: 2.9149284	total: 1.51s	remaining: 1.27s
# 543:	learn: 2.9145133	total: 1.52s	remaining: 1.27s
# 544:	learn: 2.9132303	total: 1.52s	remaining: 1.27s
# 545:	learn: 2.9102468	total: 1.52s	remaining: 1.26s
# 546:	learn: 2.9087391	total: 1.52s	remaining: 1.26s
# 547:	learn: 2.9075040	total: 1.53s	remaining: 1.26s
# 548:	learn: 2.9062173	total: 1.53s	remaining: 1.26s
# 549:	learn: 2.9050046	total: 1.53s	remaining: 1.25s
# 550:	learn: 2.9044799	total: 1.53s	remaining: 1.25s
# 551:	learn: 2.9025937	total: 1.54s	remaining: 1.25s
# 552:	learn: 2.9022346	total: 1.54s	remaining: 1.24s
# 553:	learn: 2.9010520	total: 1.54s	remaining: 1.24s
# 554:	learn: 2.8998075	total: 1.54s	remaining: 1.24s
# 555:	learn: 2.8986473	total: 1.55s	remaining: 1.23s
# 556:	learn: 2.8982863	total: 1.55s	remaining: 1.23s
# 557:	learn: 2.8974576	total: 1.55s	remaining: 1.23s
# 558:	learn: 2.8947139	total: 1.55s	remaining: 1.23s
# 559:	learn: 2.8928876	total: 1.56s	remaining: 1.22s
# 560:	learn: 2.8916824	total: 1.56s	remaining: 1.22s
# 561:	learn: 2.8899178	total: 1.56s	remaining: 1.22s
# 562:	learn: 2.8884963	total: 1.56s	remaining: 1.21s
# 563:	learn: 2.8877200	total: 1.57s	remaining: 1.21s
# 564:	learn: 2.8866113	total: 1.57s	remaining: 1.21s
# 565:	learn: 2.8850805	total: 1.57s	remaining: 1.2s
# 566:	learn: 2.8847244	total: 1.57s	remaining: 1.2s
# 567:	learn: 2.8843765	total: 1.58s	remaining: 1.2s
# 568:	learn: 2.8831763	total: 1.58s	remaining: 1.2s
# 569:	learn: 2.8805317	total: 1.58s	remaining: 1.19s
# 570:	learn: 2.8798092	total: 1.58s	remaining: 1.19s
# 571:	learn: 2.8786608	total: 1.59s	remaining: 1.19s
# 572:	learn: 2.8783202	total: 1.59s	remaining: 1.19s
# 573:	learn: 2.8779836	total: 1.59s	remaining: 1.18s
# 574:	learn: 2.8754238	total: 1.59s	remaining: 1.18s
# 575:	learn: 2.8739408	total: 1.6s	remaining: 1.18s
# 576:	learn: 2.8736113	total: 1.6s	remaining: 1.17s
# 577:	learn: 2.8732875	total: 1.6s	remaining: 1.17s
# 578:	learn: 2.8729694	total: 1.61s	remaining: 1.17s
# 579:	learn: 2.8726567	total: 1.61s	remaining: 1.17s
# 580:	learn: 2.8723476	total: 1.61s	remaining: 1.16s
# 581:	learn: 2.8720456	total: 1.61s	remaining: 1.16s
# 582:	learn: 2.8717489	total: 1.62s	remaining: 1.16s
# 583:	learn: 2.8712916	total: 1.62s	remaining: 1.15s
# 584:	learn: 2.8701776	total: 1.62s	remaining: 1.15s
# 585:	learn: 2.8687423	total: 1.63s	remaining: 1.15s
# 586:	learn: 2.8676649	total: 1.63s	remaining: 1.15s
# 587:	learn: 2.8662787	total: 1.63s	remaining: 1.14s
# 588:	learn: 2.8658306	total: 1.63s	remaining: 1.14s
# 589:	learn: 2.8655390	total: 1.64s	remaining: 1.14s
# 590:	learn: 2.8652508	total: 1.64s	remaining: 1.13s
# 591:	learn: 2.8648107	total: 1.64s	remaining: 1.13s
# 592:	learn: 2.8637269	total: 1.64s	remaining: 1.13s
# 593:	learn: 2.8634434	total: 1.65s	remaining: 1.12s
# 594:	learn: 2.8624210	total: 1.65s	remaining: 1.12s
# 595:	learn: 2.8621420	total: 1.65s	remaining: 1.12s
# 596:	learn: 2.8618634	total: 1.65s	remaining: 1.11s
# 597:	learn: 2.8605228	total: 1.65s	remaining: 1.11s
# 598:	learn: 2.8600973	total: 1.66s	remaining: 1.11s
# 599:	learn: 2.8591695	total: 1.66s	remaining: 1.11s
# 600:	learn: 2.8589031	total: 1.66s	remaining: 1.1s
# 601:	learn: 2.8586017	total: 1.67s	remaining: 1.1s
# 602:	learn: 2.8576025	total: 1.67s	remaining: 1.1s
# 603:	learn: 2.8573446	total: 1.67s	remaining: 1.1s
# 604:	learn: 2.8570847	total: 1.67s	remaining: 1.09s
# 605:	learn: 2.8560408	total: 1.68s	remaining: 1.09s
# 606:	learn: 2.8544101	total: 1.68s	remaining: 1.09s
# 607:	learn: 2.8541218	total: 1.68s	remaining: 1.08s
# 608:	learn: 2.8529551	total: 1.69s	remaining: 1.08s
# 609:	learn: 2.8527027	total: 1.69s	remaining: 1.08s
# 610:	learn: 2.8520077	total: 1.69s	remaining: 1.07s
# 611:	learn: 2.8511572	total: 1.69s	remaining: 1.07s
# 612:	learn: 2.8501125	total: 1.69s	remaining: 1.07s
# 613:	learn: 2.8498662	total: 1.7s	remaining: 1.06s
# 614:	learn: 2.8491592	total: 1.7s	remaining: 1.06s
# 615:	learn: 2.8480243	total: 1.7s	remaining: 1.06s
# 616:	learn: 2.8477881	total: 1.7s	remaining: 1.06s
# 617:	learn: 2.8465579	total: 1.71s	remaining: 1.05s
# 618:	learn: 2.8455932	total: 1.71s	remaining: 1.05s
# 619:	learn: 2.8444857	total: 1.71s	remaining: 1.05s
# 620:	learn: 2.8442527	total: 1.71s	remaining: 1.04s
# 621:	learn: 2.8440238	total: 1.72s	remaining: 1.04s
# 622:	learn: 2.8437988	total: 1.72s	remaining: 1.04s
# 623:	learn: 2.8434047	total: 1.72s	remaining: 1.04s
# 624:	learn: 2.8431835	total: 1.72s	remaining: 1.03s
# 625:	learn: 2.8425164	total: 1.73s	remaining: 1.03s
# 626:	learn: 2.8421298	total: 1.73s	remaining: 1.03s
# 627:	learn: 2.8411569	total: 1.73s	remaining: 1.03s
# 628:	learn: 2.8403780	total: 1.74s	remaining: 1.02s
# 0        lsvr                  LinearSVR
# 1         svr                        SVR
# 2        dumr             DummyRegressor
# 3          rr                      Ridge
# 4          LR           LinearRegression
# 5         KNR        KNeighborsRegressor
# 6         CBR          CatBoostRegressor
# 7         abr          AdaBoostRegressor
# 8         etr        ExtraTreesRegressor
# 9         XGB               XGBRegressor
# 10        rfr      RandomForestRegressor
# 11        gbr  GradientBoostingRegressor
# 12         DT      DecisionTreeRegressor
#
#                                          model_params  fit_time  r2_train  \
# 0   {'C': 1.0, 'dual': True, 'epsilon': 0.0, 'fit_...  0.006250 -0.075193
# 1   {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...  0.005046 -0.067734
# 2   {'constant': None, 'quantile': None, 'strategy...  0.001000  0.000000
# 3   {'alpha': 1.0, 'copy_X': True, 'fit_intercept'...  0.051368  0.084260
# 4   {'copy_X': True, 'fit_intercept': True, 'n_job...  0.006535  0.084271
# 5   {'algorithm': 'auto', 'leaf_size': 30, 'metric...  0.000995  0.376752
# 6                           {'loss_function': 'RMSE'}  3.014725  0.826128
# 7   {'base_estimator': 'deprecated', 'estimator': ...  0.027045  0.486056
# 8   {'bootstrap': False, 'ccp_alpha': 0.0, 'criter...  0.213094  0.835881
# 9   {'objective': 'reg:squarederror', 'base_score'...  0.148160  0.835938
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'criteri...  0.374641  0.735606
# 11  {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': ...  0.153911  0.816317
# 12  {'ccp_alpha': 0.0, 'criterion': 'squared_error...  0.001986  0.835941
#
#     mae_train  rmse_train    r2_val   mae_val  rmse_val
# 0    1.772284    6.617675 -0.078798  1.681481  6.156749
# 1    1.788831    6.594681 -0.070110  1.694209  6.131907
# 2    3.022298    6.382081 -0.000224  2.674293  5.928297
# 3    2.976969    6.107287  0.135599  2.744499  5.511110
# 4    2.981307    6.107250  0.136435  2.747486  5.508444
# 5    2.095228    5.038400  0.269713  2.135731  5.065568
# 6    0.811376    2.661197  0.364628  1.906532  4.724928
# 7    1.951550    4.575307  0.367523  1.882219  4.714155
# 8    0.514079    2.585486  0.396791  1.831406  4.603786
# 9    0.510015    2.585036  0.457457  1.552019  4.366147
# 10   1.183658    3.281620  0.562956  1.523522  3.918715
# 11   0.892374    2.735246  0.621597  1.478337  3.646353
# 12   0.503515    2.585010  0.659557  1.182422  3.458624

# %%
df_classics.to_csv('df_classics_initial results_angles.csv')

# %%
df_classics.set_index('model_name_pretty', inplace=True)

# R^2 Plot for train and test, sorted from highest to lowest for train
df_sorted_r2 = df_classics.sort_values('r2_val', ascending=False)
ax_r2 = df_sorted_r2[['r2_train', 'r2_val']].plot(kind='bar', figsize=(10, 6))
ax_r2.set_ylabel('R^2 Score')
ax_r2.set_title('R^2 Score for Train and Test')
ax_r2.legend(["R^2 Train", "R^2 Test"])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('angles_r2_score_comparison.png')
plt.show()

# MAE Plot for train and test, sorted from lowest to highest for train
df_sorted_mae = df_classics.sort_values('mae_train', ascending=True)
ax_mae = df_sorted_mae[['mae_train', 'mae_val']].plot(kind='bar', figsize=(10, 6))
ax_mae.set_ylabel('MAE')
ax_mae.set_title('MAE for Train and Test')
ax_mae.legend(["MAE Train", "MAE Test"])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('angles_mae_comparison.png')
plt.show()

# RMSE Plot for train and test, sorted from lowest to highest for train
df_sorted_rmse = df_classics.sort_values('rmse_train', ascending=True)
ax_rmse = df_sorted_rmse[['rmse_train', 'rmse_val']].plot(kind='bar', figsize=(10, 6))
ax_rmse.set_ylabel('RMSE')
ax_rmse.set_title('RMSE for Train and Test')
ax_rmse.legend(["RMSE Train", "RMSE Test"])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('angles_rmse_comparison.png')
plt.show()

# %%
classic_models
# Out:
# OrderedDict([('dumr', DummyRegressor()),
#              ('rr', Ridge()),
#              ('abr', AdaBoostRegressor()),
#              ('gbr', GradientBoostingRegressor()),
#              ('rfr', RandomForestRegressor()),
#              ('etr', ExtraTreesRegressor()),
#              ('DT', DecisionTreeRegressor()),
#              ('KNR', KNeighborsRegressor()),
#              ('svr', SVR()),
#              ('lsvr', LinearSVR()),
#              ('CBR', <catboost.core.CatBoostRegressor at 0x22e96dfd2d0>),
#              ('LR', LinearRegression()),
#              ('XGB',
#               XGBRegressor(base_score=None, booster=None, callbacks=None,
#                            colsample_bylevel=None, colsample_bynode=None,
#                            colsample_bytree=None, device=None, early_stopping_rounds=None,
#                            enable_categorical=False, eval_metric=None, feature_types=None,
#                            gamma=None, grow_policy=None, importance_type=None,
#                            interaction_constraints=None, learning_rate=None, max_bin=None,
#                            max_cat_threshold=None, max_cat_to_onehot=None,
#                            max_delta_step=None, max_depth=None, max_leaves=None,
#                            min_child_weight=None, missing=nan, monotone_constraints=None,
#                            multi_strategy=None, n_estimators=None, n_jobs=None,
#                            num_parallel_tree=None, random_state=None, ...))])

# %%
def plot_pred_act(act, pred, model, reg_line=True, label=''):
    xy_max = np.max([np.max(act), np.max(pred)])

    plot = plt.figure(figsize=(6,6))
    plt.plot(act, pred, 'o', ms=9, mec='k', mfc='silver', alpha=0.4)
    plt.plot([0, xy_max], [0, xy_max], 'k--', label='ideal')
    if reg_line:
        polyfit = np.polyfit(act, pred, deg=1)
        reg_ys = np.poly1d(polyfit)(np.unique(act))
        plt.plot(np.unique(act), reg_ys, alpha=0.8, label='linear fit')
    plt.axis('scaled')
    plt.xlabel(f'Actual Angle Deviation (deg)')
    plt.ylabel(f'Predicted Anlge Deviation (deg)')
    plt.title(f'{type(model).__name__}, r2: {r2_score(act, pred):0.4f}')
    plt.legend(loc='upper left')
    
    return plot

# %%
for row in range(df_classics.shape[0]):
    model_name = df_classics.iloc[row]['model_name']

    model = classic_models[model_name]
    y_act_val = y_val
    y_pred_val = model.predict(X_val)

    plot = plot_pred_act(y_act_val, y_pred_val, model, reg_line=True, label='$\mathrm{C}_\mathrm{p}$ (MPa)')
    plt.savefig(f"angles_{model_name}_plot.png", dpi=300, bbox_inches='tight')
    plt.show()
